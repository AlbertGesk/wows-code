# %%
from glob import glob
import pyterrier as pt
from tira.third_party_integrations import ensure_pyterrier_is_loaded

# %%
ensure_pyterrier_is_loaded()

ds_id = "radboud-validation-20251114-training"

# ds_id = "spot-check-20251122-training"
dataset = pt.datasets.get_dataset(f"irds:ir-lab-wise-2025/{ds_id}")
topics = dataset.get_topics("text")
qrels = dataset.get_qrels()
# Out:
# Java started and loaded: pyterrier.java.colab, pyterrier.java, pyterrier.java.24, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]

# %%
runs = {}

for run_name in glob(f'output/runs/{ds_id}/*/run.txt.gz'):
    runs[run_name.split('/')[-2]] = pt.io.read_results(run_name)

# %%
pt.Experiment(
    list(runs.values()),
    topics,
    qrels,
    ["ndcg_cut.10"],
    list(runs.keys())
)
# Out:
#                                                  name  ndcg_cut.10
# 0      pyterrier-on-default_text-with-(BM25-Bo1-BM25)     0.334121
# 1       pyterrier-on-default_text-with-(BM25-Bo1-DPH)     0.455540
# 2      pyterrier-on-default_text-with-(BM25-RM3-BM25)     0.308059
# 3       pyterrier-on-default_text-with-(BM25-RM3-DPH)     0.438784
# 4       pyterrier-on-default_text-with-(DPH-Bo1-BM25)     0.416735
# 5       pyterrier-on-default_text-with-(DPH-RM3-BM25)     0.397246
# 6        pyterrier-on-default_text-with-(DPH-RM3-DPH)     0.474432
# 7                 pyterrier-on-default_text-with-BM25     0.422390
# 8          pyterrier-on-default_text-with-DPH-Bo1-DPH     0.494674
# 9   pyterrier-on-default_text-with-DPH-Bo1-DPH-ref...     0.494674
# 10  pyterrier-on-default_text-with-DPH-RM3-DPH-no-...     0.474432
# 11      pyterrier-on-description-with-(BM25-Bo1-BM25)     0.240287
# 12       pyterrier-on-description-with-(BM25-Bo1-DPH)     0.212247
# 13      pyterrier-on-description-with-(BM25-RM3-BM25)     0.242857
# 14       pyterrier-on-description-with-(BM25-RM3-DPH)     0.229822
# 15       pyterrier-on-description-with-(DPH-Bo1-BM25)     0.232808
# 16       pyterrier-on-description-with-(DPH-RM3-BM25)     0.226331
# 17        pyterrier-on-description-with-(DPH-RM3-DPH)     0.201658
# 18                 pyterrier-on-description-with-BM25     0.240660
# 19          pyterrier-on-description-with-DPH-Bo1-DPH     0.194441
# 20            pyterrier-on-title-with-(BM25-Bo1-BM25)     0.386461
# 21             pyterrier-on-title-with-(BM25-Bo1-DPH)     0.307812
# 22            pyterrier-on-title-with-(BM25-RM3-BM25)     0.386359
# 23             pyterrier-on-title-with-(BM25-RM3-DPH)     0.333326
# 24             pyterrier-on-title-with-(DPH-Bo1-BM25)     0.364485
# 25              pyterrier-on-title-with-(DPH-Bo1-DPH)     0.272987
# 26             pyterrier-on-title-with-(DPH-RM3-BM25)     0.375300
# 27              pyterrier-on-title-with-(DPH-RM3-DPH)     0.301183
# 28                       pyterrier-on-title-with-BM25     0.384174
