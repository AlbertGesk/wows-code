# %% [markdown]
# # Review dataset

# %%
import click
import pyterrier as pt
from pathlib import Path
from tirex_tracker import tracking, ExportFormat
from tira.third_party_integrations import ir_datasets, ensure_pyterrier_is_loaded
from tqdm import tqdm

from pathlib import Path

ensure_pyterrier_is_loaded(is_offline=False)

def extract_text_of_document(doc, field):
    # ToDo: here one can make modifications to the document representations
    if field == "default_text":
        return doc.default_text()
    elif field == "title":
        return doc.title
    elif field == "description":
        return doc.description
    

def get_index(dataset, field, output_path):
    index_dir = output_path / "indexes" / f"{dataset}-on-{field}"
    if not index_dir.is_dir():
        print("Build new index")
        docs = []
        dataset = ir_datasets.load(f"ir-lab-wise-2025/{dataset}")

        for doc in tqdm(dataset.docs_iter(), "Pre-Process Documents"):
            docs.append({"docno": doc.doc_id, "text": extract_text_of_document(doc, field)})

        with tracking(export_file_path=index_dir / "index-metadata.yml", export_format=ExportFormat.IR_METADATA):
            pt.IterDictIndexer(str(index_dir.absolute()), meta={'docno' : 100}, verbose=True).index(docs)

    return pt.IndexFactory.of(str(index_dir.absolute()))


dataset="spot-check-20251122-training"
text_field_to_retrieve="title"
retrieval_model="BM25"
output=Path("output")

index = get_index(dataset, text_field_to_retrieve, output)
# Out:
# Java started and loaded: pyterrier.java.colab, pyterrier.java, pyterrier.java.24, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# ---------------------------------------------------------------------------
# JavaException                             Traceback (most recent call last)
# Cell In[1], line 43
#      40 retrieval_model="BM25"
#      41 output=Path("output")
# ---> 43 index = get_index(dataset, text_field_to_retrieve, output)
#
# Cell In[1], line 35, in get_index(dataset, field, output_path)
#      32     with tracking(export_file_path=index_dir / "index-metadata.yml", export_format=ExportFormat.IR_METADATA):
#      33         pt.IterDictIndexer(str(index_dir.absolute()), meta={'docno' : 100}, verbose=True).index(docs)
# ---> 35 return pt.IndexFactory.of(str(index_dir.absolute()))
#
# File /usr/local/lib/python3.10/dist-packages/pyterrier/utils.py:142, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     139 @wraps(fn)
#     140 def _wrapper(*args, **kwargs):
#     141     decorator(fn)
# --> 142     return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/pyterrier/terrier/index_factory.py:109, in IndexFactory.of(indexlike, memory)
#     107 if memory or (isinstance(memory, list) and len(memory) > 0): #MEMORY CAN BE A LIST?
#     108     pt.terrier.J.IndexOnDisk.setIndexLoadingProfileAsRetrieval(False)
# --> 109 index = pt.terrier.J.IndexFactory.of(indexlike)
#     111 # noop if memory is False
#     112 pt.terrier.J.IndexOnDisk.setIndexLoadingProfileAsRetrieval(load_profile)
#
# File jnius/jnius_export_class.pxi:1187, in jnius.JavaMultipleMethod.__call__()
#
# File jnius/jnius_export_class.pxi:896, in jnius.JavaMethod.__call__()
#
# File jnius/jnius_export_class.pxi:1062, in jnius.JavaMethod.call_staticmethod()
#
# File jnius/jnius_utils.pxi:79, in jnius.check_exception()
#
# JavaException: JVM exception occurred: java.lang.UnsupportedOperationException: No IndexLoaders were supported for indexref /workspaces/wows-code/ecir26/ks-golden-retrievals/output/indexes/spot-check-20251122-training-on-title; It may be your ref has the wrong location. Alternatively, Terrier is misconfigured - did you import the correct package to deal with this indexref?
# java.lang.UnsupportedOperationException: No IndexLoaders were supported for indexref /workspaces/wows-code/ecir26/ks-golden-retrievals/output/indexes/spot-check-20251122-training-on-title; It may be your ref has the wrong location. Alternatively, Terrier is misconfigured - did you import the correct package to deal with this indexref?
# 	org.terrier.structures.IndexFactory.of(IndexFactory.java:143)
# 	org.terrier.structures.IndexFactory.of(IndexFactory.java:114)

# %% [markdown]
# Todos:
# - load pyterrier
# - indexing
#     -
