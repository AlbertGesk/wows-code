# %% [markdown]
# # Research Question
#
# How does the two relevance feedback-based transformers, Bo1 and RM3, inflluence retrieval result (nDCG@10) when implemented in a DPH-based retriever-rewriter-retriever pipeline?
#
#
#
#
#
# What is the influence of choice of pseudo-relevance feedback transformer in a retrieval pipeline
#
# Two pseudo-relevance feedback transformers
