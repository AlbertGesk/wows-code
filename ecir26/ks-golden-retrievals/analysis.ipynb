# %%
from glob import glob
import pyterrier as pt
from tira.third_party_integrations import ensure_pyterrier_is_loaded

# %%
ensure_pyterrier_is_loaded()

# ds_id = "radboud-validation-20251114-training"

ds_id = "spot-check-20251122-training"
dataset = pt.datasets.get_dataset(f"irds:ir-lab-wise-2025/{ds_id}")
topics = dataset.get_topics("text")
qrels = dataset.get_qrels()

# %%
runs = {}

for run_name in glob(f'output/runs/{ds_id}/*/run.txt.gz'):
    runs[run_name.split('/')[-2]] = pt.io.read_results(run_name)

# %%
pt.Experiment(
    list(runs.values()),
    topics,
    qrels,
    ["ndcg_cut.10"],
    list(runs.keys())
)
# Out:
#                                                 name  ndcg_cut.10
# 0                     pyterrier-BM25-on-default_text     0.766625
# 1  pyterrier-BM25-on-default_text-porter-terrier-...     0.813602
# 2  pyterrier-BM25-on-default_text-porter-terrier-...     0.766625
# 3  pyterrier-BM25-on-default_text-stem-stop-with-bo1     0.813602
# 4  pyterrier-BM25-on-default_text-stem-stop-with-...     0.765102
# 5            pyterrier-BM25-on-default_text-with-bo1     0.813602
# 6          pyterrier-BM25-on-default_text-with-no-qe     0.766625
